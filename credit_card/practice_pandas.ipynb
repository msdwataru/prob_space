# %%
import pandas as pd

# %%
df=pd.read_csv("./train_data.csv")

# %%
df.describe()
# Out:
#                 id              X1            X2            X3            X4  \
# count  27000.00000    27000.000000  27000.000000  27000.000000  27000.000000
# mean   13499.50000   166856.284444      1.603074      1.853741      1.551556
# std     7794.37297   129363.239705      0.489269      0.789234      0.521767
# min        0.00000    10000.000000      1.000000      0.000000      0.000000
# 25%     6749.75000    50000.000000      1.000000      1.000000      1.000000
# 50%    13499.50000   140000.000000      2.000000      2.000000      2.000000
# 75%    20249.25000   240000.000000      2.000000      2.000000      2.000000
# max    26999.00000  1000000.000000      2.000000      6.000000      3.000000
#
#                  X5            X6            X7            X8            X9  \
# count  27000.000000  27000.000000  27000.000000  27000.000000  27000.000000
# mean      35.502407     -0.012519     -0.128185     -0.162370     -0.216037
# ...

# %%
df[:5][["id","X1"]]
# Out:
#    id      X1
# 0   0   20000
# 1   1  120000
# 2   2   90000
# 3   3   50000
# 4   4   50000

# %%
df.shape
# Out:
# (27000, 25)

# %%
df.iloc[:4,:-1]
# Out:
#    id      X1  X2  X3  X4  X5  X6  X7  X8  X9  ...    X14    X15    X16  \
# 0   0   20000   2   2   1  24   2   2  -1  -1  ...    689      0      0
# 1   1  120000   2   2   2  26  -1   2   0   0  ...   2682   3272   3455
# 2   2   90000   2   2   2  34   0   0   0   0  ...  13559  14331  14948
# 3   3   50000   1   2   1  57  -1   0  -1   0  ...  35835  20940  19146
#
#      X17   X18    X19    X20   X21   X22   X23
# 0      0     0    689      0     0     0     0
# 1   3261     0   1000   1000  1000     0  2000
# 2  15549  1518   1500   1000  1000  1000  5000
# 3  19131  2000  36681  10000  9000   689   679
#
# [4 rows x 24 columns]

# %%
df.query("X1 > 100000")
# Out:
#           id      X1  X2  X3  X4  X5  X6  X7  X8  X9  ...     X15     X16  \
# 1          1  120000   2   2   2  26  -1   2   0   0  ...    3272    3455
# 5          5  500000   1   1   2  29   0   0   0   0  ...  542653  483003
# 7          7  140000   2   3   1  28   0   0   2   0  ...   12211   11793
# 9          9  200000   2   3   2  34   0   0   2   0  ...    2513    1828
# 10        10  260000   2   1   2  51  -1  -1  -1  -1  ...    8517   22287
# 12        12  250000   1   1   2  29   0   0   0   0  ...   59696   56875
# 15        15  360000   2   1   1  49   1  -2  -2  -2  ...       0       0
# 16        16  180000   2   1   2  29   1  -2  -2  -2  ...       0       0
# 17        17  130000   2   3   2  39   0   0   0   0  ...   20616   11802
# 19        19  450000   2   1   1  40  -2  -2  -2  -2  ...     560       0
# 25        25  230000   2   1   2  27  -1  -1  -1  -1  ...   15339   14307
# 28        28  500000   2   2   1  54  -2  -2  -2  -2  ...    7521   71439
# ...
